# %%
gakuseki=input("学籍番号を入力してください")
name=input("名前を入力してください")
suugaku=int(input("数学の点数を入れてください"))
eigo=int(input("英語の点数を入れてください"))
kokugo=int(input("国語の点数を入れてください"))
data=[kokugo,suugaku,eigo]
ave=sum(data)/len(data)
print(gakuseki,name,suugaku,eigo,kokugo,sum(data),ave)
