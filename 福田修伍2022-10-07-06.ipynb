# %%
money = int(input('金額(円)を入力してください>'))
print('金額：',money,'円',sep='')

shihei_s = [10000,5000,1000,500,100,50,10,5,1]

for shihei in shihei_s:
    maisuu = money // shihei
    money %= shihei
    print(shihei, '円：',maisuu,'枚',sep='' )
